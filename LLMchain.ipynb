# %% [markdown]
# <a href="https://colab.research.google.com/github/affanmohd65/LangchainTut/blob/main/LLMchain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

class fakeLLM:

    def __init__(self):
        print("LLM created")

    def predict(self, prompt):

        response_list = [
            "Delhi is capital of India",
            "IPL is good",
            "AI is booming"
        ]

        return {
            "response": random.choice(response_list)
        }

llm = fakeLLM()

print(llm.predict("what is capital of india?"))
# Out:
# LLM created
# {'response': 'IPL is good'}

# %%
class fakePrompt:
  def __init__(self,template,input_variables):
    self.template=template
    self.input_variables=input_variables
  def format(self, input_dict):
    return self.template.format(**input_dict)

# %%
template=fakePrompt(
    template='write a {length} poem about {topic}',
    input_variables=['length','topic']
)

# %%
prompt = template.format({'length':'short','topic': 'india'})

# %%
llm=fakeLLM()
# Out:
# LLM created

# %%
llm.predict(prompt)
# Out:
# {'response': 'Delhi is capital of India'}

# %%
class fakeChain:

  def __init__(self,llm,prompt):
    self.llm=llm
    self.prompt=prompt

  def run(self, input_dict):
    final_prompt=self.prompt.format(input_dict)
    result=self.llm.predict(final_prompt)

    return result['response']

# %%
template=fakePrompt(
    template='write a {length} poem about {topic}',
    input_variables=['length','topic']
)

# %%
llm=fakeLLM()
# Out:
# LLM created

# %%
chain=fakeChain(llm,template)

# %%
chain.run({'length':'short', 'topic':'india'})
# Out:
# 'IPL is good'
